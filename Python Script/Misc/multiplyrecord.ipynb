# %%
import pandas as pd
import numpy as np
import datetime as dt
import multiprocessing as mp

# %%
if __name__ == '__main__':

    initial_start_time = dt.datetime.now()
    print(f"Execution begins to generate bulk data at: {dt.datetime.now().time()}")

    # Read data
    ihub = pd.read_excel("SampleData_Security_IHUB.xlsx") 
    crd = pd.read_excel("SampleData_Security_CRD.xlsx")
    
    start_time = dt.datetime.now()
    multiplied_fact = pd.concat([ihub] * 100000, ignore_index=True)
    print(f"Execution time for the multiplication process: {(dt.datetime.now() - start_time).total_seconds()} seconds")
    print("Multiplication done")
    start_time = dt.datetime.now()
    multiplied_fact['I.INSTRUMENTID'] = multiplied_fact['I.INSTRUMENTID'] + ((multiplied_fact.index // 26))
    multiplied_fact.to_csv('SampleData_Seurity_IHUB_1.3Mtest.csv', index=False)
    print(f"Execution time for the multiplication process: {(dt.datetime.now() - start_time).total_seconds()} seconds")
    multiplied_fact.drop(index=multiplied_fact.index, inplace=True)
    print("Fact Done")
# Out:
# Execution begins to generate bulk data at: 12:49:53.136143
# Execution time for the multiplication process: 82.678412 seconds
# Multiplication done
# Execution time for the multiplication process: 27.100042 seconds
# Fact Done

# %%
ihub
# Out:
#     I.INSTRUMENTID  I.FISHERSECID I.SOURCESECID    I.CUSIP        I.ISIN
# 0           132210         132210     169400VQT        NaN  BMG2113B1081  \
# 1           123241         123241     16938L1BT        NaN  BMG2109G1033
# 2           126688         126688     82675CJKT        NaN  BMG8162K1137
# 3           192497         192497     99948B4BT        NaN  BMG5369T1788
# 4           144812         144812     999546AAT        NaN  KE0000000075
# 5           144394         144394     999DC2FBT        NaN  KE0000000067
# 6           233218         233218     99930443T        NaN  CH1101098163
# 7           124707         124707     05942T1CT        NaN  KE0000000059
# 8           152722         152722     999CECDAT        NaN  KE0000000091
# 9           144396         144396     999971B5T        NaN  KE0000000216
# 10          144397         144397     999304A5T        NaN  KE0000000554
# 11          168058         168058     9995E922T        NaN  CH0319416936
# 12          190197         190197     999D36F9T        NaN  CH0006372897
# 13          144398         144398     999313A8T        NaN  KE0000000315
# 14          239373         239373     999CC0D5T        NaN  CH1129677105
# 15          183442         183442     99960924T        NaN  CH0042615283
# 16          144399         144399     99915FA3T        NaN  KE1000001402
# 17          242003         242003     9993F500T        NaN  KE0000000448
# 18          135840         135840     9997CBAFT        NaN  BMG6844T1229
# 19          267429         267429     999E1913T        NaN  CH1176493729
# 20          100001         100001           NaN  3128MJGP9  US3128MJGP90
# 21          100006         100006           NaN  31403DUK3  US31403DUK35
# 22          238910         238910           NaN  999C6DECT  KYG8208B1014
# 23          239189         239189     999AA4E8T  999AA4E8T  KYG1146Y1017
# 24          275792         275792           NaN  999D4DE4T  KYG4231A1031
# 25          276225         276225     999BEEA2T  999BEEA2T  KYG4212K1040
#
#    I.FISHERTICKER  I.SEDOL                                  I.BLOOMBERGTICKER
# 0       SD6535517  6535517                                            1193 HK  \
# 1       SD6460794  6460794                                             384 HK
# 2       SDB4X3RF7  B4X3RF7                                             460 HK
# 3       SDBFWY6S4  BFWY6S4                                             582 HK
# 4       SD6069287  6069287                                            BATK KN
# 5       SDB1JD0H3  B1JD0H3                                            BCBL KN
# 6       SDBP0QDP8  BP0QDP8                                            BEAN SW
# 7       SD6074623  6074623                                            BMBC KN
# 8       SD6188397  6188397                                            CFCB KN
# 9       SDB04NN72  B04NN72                                            EABL KN
# 10      SDB0WCDV5  B0WCDV5                                           EQBNK KN
# 11      SDBYQ8481  BYQ8481                                            FHZN SW
# 12      SD5206621  5206621                                            INRN SW
# 13      SDB1VG917  B1VG917                                            KNCB KN
# 14      SDBNZGVK0  BNZGVK0                                            MEDX SW
# 15      SDB92M6T7  B92M6T7                                            ROSE SW
# 16      SDB2QN3J6  B2QN3J6                                          SAFCOM KN
# 17      SD6839026  6839026                                            SCBL KN
# 18      SDB8180J7  B8180J7  SDB8180J7                                     ...
# 19      SDBMXVKB4  BMXVKB4  SDBMXVKB4                                     ...
# 20      3128MJGP9      NaN  3128MJGP9                                     ...
# 21      31403DUK3      NaN  31403DUK3                                     ...
# 22      SDBKPQZT6  BKPQZT6                                            9618 HK
# 23      SDBGDY260  BGDY260                                            6160 HK
# 24      SDBQWN4M8  BQWN4M8                                            2255 HK
# 25      SDBP6TX62  BP6TX62                                            2273 HK
#
#    I.FISHERINSTRUMENTTYPECODE                    I.SHORTNAME  ...
# 0                          EQ             CHINA RES GAS GP L  ...  \
# 1                          EQ             CHINA GAS HOLDINGS  ...
# 2                          EQ              SIHUAN PHARM HLDG  ...
# 3                          EQ             SHIN HWA WORLD LTD  ...
# 4                          EQ             BRIT AMER TOBAC.KE  ...
# 5                          EQ                ABSA BANK KENYA  ...
# 6                          EQ              BELIMO HOLDING AG  ...
# 7                          EQ             BAMBURI CEMENT LTD  ...
# 8                          EQ              STANBIC HLDGS PLC  ...
# 9                          EQ     EAST AFRICAN BREWERIES LTD  ...
# 10                         EQ             EQUITY GROUP HLDGS  ...
# 11                         EQ             FLUGHAFEN ZURICH A  ...
# 12                         EQ              INTERROLL HLDG AG  ...
# 13                         EQ                  KCB GROUP PLC  ...
# 14                         EQ                      MEDMIX AG  ...
# 15                         EQ                 ZUR ROSE GP AG  ...
# 16                         EQ                  SAFARICOM PLC  ...
# 17                         EQ  STANDARD CHARTERED BANK KENYA  ...
# 18                         EQ             PACIFIC CENTURY PR  ...
# 19                         EQ              BACHEM HOLDING AG  ...
# 20                         FI  FHLMC GIANT MBS  GOLD COMB 30  ...
# 21                         FI   FNMA SUPER       LNG 30 YEAR  ...
# 22                         EQ                     JD.COM INC  ...
# 23                         EQ                    BEIGENE LTD  ...
# 24                         EQ   HAICHANG OCEAN PARK HOLDINGS  ...
# 25                         EQ              GUSHENGTANG HLDGS  ...
#
#    FISHERINDICATOR FISHERINSTRUMENTTYPEDESC  ASSETGROUPTYPE  FISHERSECTOR
# 25         3510.0           351020.0    2023-05-19 2023-05-19 02:41:35
#
#                      I.CREATEBY                   I.UPDATEBY
# 0   pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 1   pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 2   pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 3   pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 4   pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 5   pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 6   pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 7   pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 8   pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 9   pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 10  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 11  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 12  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 13  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 14  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 15  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 16  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 17  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 18  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 19  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 20  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 21  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 22  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 23  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 24  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
# 25  pl_sourceblob_ihub_security  pl_sourceblob_ihub_security
#
# [26 rows x 50 columns]

# %%
if __name__ == '__main__':

    initial_start_time = dt.datetime.now()
    print(f"Execution begins to generate bulk data at: {dt.datetime.now().time()}")

    # Read data 
    crd = pd.read_excel("SampleData_Security_CRD.xlsx")
    
    start_time = dt.datetime.now()
    multiplied_fact = pd.concat([crd] * 100, ignore_index=True)
    print(f"Execution time for the multiplication process: {(dt.datetime.now() - start_time).total_seconds()} seconds")
    print("Multiplication done")
    start_time = dt.datetime.now()
    multiplied_fact['EXT_SEC_ID'] = multiplied_fact['EXT_SEC_ID'] + ((multiplied_fact.index // 26))
    multiplied_fact.to_csv('SampleData_Security_CRD_1.3Mtest.csv', index=False)
    print(f"Execution time for the multiplication process: {(dt.datetime.now() - start_time).total_seconds()} seconds")
    multiplied_fact.drop(index=multiplied_fact.index, inplace=True)
    print("Fact Done")
# Out:
# Execution begins to generate bulk data at: 14:57:32.184347
# Execution time for the multiplication process: 0.079334 seconds
# Multiplication done
# Execution time for the multiplication process: 0.171601 seconds
# Fact Done
