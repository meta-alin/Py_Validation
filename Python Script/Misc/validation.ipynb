# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DoubleType

# Create a SparkSession
spark = SparkSession.builder.getOrCreate()

expected_schema = StructType([
    StructField("ACCT_CD", IntegerType(), nullable=True),
    StructField("EXT_SEC_ID", IntegerType(), nullable=True),
    StructField("ASOF_DATE", StringType(), nullable=True),
    StructField("LONG_SHORT_IND", StringType(), nullable=True),
    StructField("QTY_SOD", IntegerType(), nullable=True),
    StructField("COST", DoubleType(), nullable=True),
    StructField("UNIT_COST", DoubleType(), nullable=True),
    StructField("MKT_VAL_SOD", DoubleType(), nullable=True),
    StructField("UNREALIZED_GAIN_LOSS", StringType(), nullable=True)
])

df = spark.read.csv("CRD_Position_202212124.csv", nullValue="", header=True, inferSchema=True)

print('Data frame schema: ', df.schema)
print('Expected Schema: ', expected_schema)

if df.schema == expected_schema:
    print("Schema validation successful")
else:
    mismatched_row = df.filter(~(df["ACCT_CD"].cast(IntegerType()).isNotNull() &
                                 df["EXT_SEC_ID"].cast(StringType()).isNotNull() &
                                 df["ASOF_DATE"].cast(IntegerType()).isNotNull()&
                                 df["LONG_SHORT_IND"].cast(IntegerType()).isNotNull() &
                                 df["QTY_SOD"].cast(StringType()).isNotNull() &
                                 df["COST"].cast(IntegerType()).isNotNull()&
                                 df["UNIT_COST"].cast(IntegerType()).isNotNull() &
                                 df["MKT_VAL_SOD"].cast(StringType()).isNotNull() &
                                 df["UNREALIZED_GAIN_LOSS"].cast(IntegerType()).isNotNull()))
    if  mismatched_row.count() > 0:
        print("Schema validation failed.")
        print("Mismatched row:")
        mismatched_row.show()
        mismatched_columns = set(df.schema.fieldNames()).symmetric_difference(set(expected_schema.fieldNames()))
    if  len(mismatched_columns)>0:
        print("Schema validation failed.")
        print("Mismatched columns: ", mismatched_columns)
        print("Sample data from mismatched columns:")
        # Show sample data from mismatched columns
        for column_name in mismatched_columns:
            print(f"Column: {column_name}")
            df.select(column_name).show(10, truncate=False)

# if all(col in df.columns for col in expected_schema.fieldNames()):
#     mismatched_row = df.filter(~(df["Id"].cast(IntegerType()).isNotNull() &
#                                  df["Name"].cast(StringType()).isNotNull() &
#                                  df["Name_id"].cast(IntegerType()).isNotNull()))

#     if mismatched_row.count() > 0:
#         print("Schema validation failed.")
#         print("Mismatched row:")
#         mismatched_row.show()
#     else:
#         print("Schema validation successful")
# else:
#     print("Schema validation failed. Mismatched columns.")
# Out:
# Data frame schema:  StructType([StructField('ACCT_CD', IntegerType(), True), StructField('EXT_SEC_ID', IntegerType(), True), StructField('ASOF_DATE', StringType(), True), StructField('LONG_SHORT_IND', StringType(), True), StructField('QTY_SOD', IntegerType(), True), StructField('COST', DoubleType(), True), StructField('UNIT_COST', DoubleType(), True), StructField('MKT_VAL_SOD', DoubleType(), True), StructField('UNREALIZED_GAIN_LOSS', StringType(), True), StructField('ACCRUED_INTEREST', StringType(), True)])
# Expected Schema:  StructType([StructField('ACCT_CD', IntegerType(), True), StructField('EXT_SEC_ID', IntegerType(), True), StructField('ASOF_DATE', StringType(), True), StructField('LONG_SHORT_IND', StringType(), True), StructField('QTY_SOD', IntegerType(), True), StructField('COST', DoubleType(), True), StructField('UNIT_COST', DoubleType(), True), StructField('MKT_VAL_SOD', DoubleType(), True), StructField('UNREALIZED_GAIN_LOSS', StringType(), True)])
# Schema validation failed.
# Mismatched row:
# +-------+----------+----------+--------------+-------+--------+------------+-----------+--------------------+----------------+
# |ACCT_CD|EXT_SEC_ID| ASOF_DATE|LONG_SHORT_IND|QTY_SOD|    COST|   UNIT_COST|MKT_VAL_SOD|UNREALIZED_GAIN_LOSS|ACCRUED_INTEREST|
# +-------+----------+----------+--------------+-------+--------+------------+-----------+--------------------+----------------+
# |   1465|     54655|02/08/2022|             L|   1796|31953.96| 17.79173719| 19793.5364|         -12160.4236|            null|
# |   1465|     65898|02/08/2022|             L|    332| 9249.13|  27.8588253|   23528.84|   14279.71/23528.84|            null|
# |   1465|    217927|02/08/2022|             L|    146| 5924.25| 40.57705479|    10497.4|             4573.15|            null|
# |   1465|     72877|02/08/2022|             L|    970|52134.48|  53.7468866|    58035.1|             5900.62|            null|
# |   1465|     74075|02/08/2022|             L|    442|72279.11|163.52739819|    74344.4|             2065.29|            null|
# |   1465|     74791|02/08/2022|             L|    758|29415.55|  38.8067942|    1111.58|             9250.03|            null|
# |   1465|     75065|02/08/2022|             L|    918|53684.16| 58.47947712|    32726.7|           -20957.46|            null|
# |   1465|    137217|02/08/2022|             L|     99|31819.92|321.41333333|  3333333.0|            16131.72|            null|
# |   1465|    115926|02/08/2022|             L|   1074|41898.41| 39.01155493| 48506.7804|           6608.3704|            null|
# |   1465|     79188|02/08/2022|             L|   2222|17911.69|373.16020833|   26316.96|             8405.27|            null|
# |   1465|     79524|02/08/2022|             L|    558|35129.47| 62.95603943|   29479.14|            -5650.33|            null|
# |   1465|    103044|02/08/2022|             S|   -231|44461.66|192.47471861|   46010.58|             1548.92|            null|
# |   1465|    205265|02/08/2022|             S|   -456|29510.47|146.09143564|   22415.94|            -7094.53|            null|
# +-------+----------+----------+--------------+-------+--------+------------+-----------+--------------------+----------------+
#
# Schema validation failed.
# Mismatched columns:  {'ACCRUED_INTEREST'}
# Sample data from mismatched columns:
# Column: ACCRUED_INTEREST
# +----------------+
# |ACCRUED_INTEREST|
# +----------------+
# |null            |
# |null            |
# |null            |
# |null            |
# |null            |
# |null            |
# |null            |
# |null            |
# |null            |
# |null            |
# +----------------+
# only showing top 10 rows

# %%
ACCT_CD	EXT_SEC_ID	ASOF_DATE	LONG_SHORT_IND	QTY_SOD	COST	UNIT_COST	MKT_VAL_SOD	UNREALIZED_GAIN_LOSS	ACCRUED_INTEREST
# Out:
#   Cell In[11], line 1
#     ACCT_CD	EXT_SEC_ID	ASOF_DATE	LONG_SHORT_IND	QTY_SOD	COST	UNIT_COST	MKT_VAL_SOD	UNREALIZED_GAIN_LOSS	ACCRUED_INTEREST
#            	^
# SyntaxError: invalid syntax

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DoubleType

# Create a SparkSession
spark = SparkSession.builder.getOrCreate()

expected_schema = StructType([
    StructField("ACCT_CD", IntegerType(), nullable=True),
    StructField("EXT_SEC_ID", IntegerType(), nullable=True),
    StructField("ASOF_DATE", StringType(), nullable=True),
    StructField("LONG_SHORT_IND", StringType(), nullable=True),
    StructField("QTY_SOD", IntegerType(), nullable=True),
    StructField("COST", DoubleType(), nullable=True),
    StructField("UNIT_COST", DoubleType(), nullable=True),
    StructField("MKT_VAL_SOD", DoubleType(), nullable=True),
    StructField("UNREALIZED_GAIN_LOSS", StringType(), nullable=True)
])

df = spark.read.csv("CRD_Position_202212124.csv", nullValue="", header=True, inferSchema=True)

print('Data frame schema: ', df.schema)
print('Expected Schema: ', expected_schema)

try:
    if (col in df.columns for col in expected_schema.fieldNames()):
        mismatched_row = df.filter(~(df["ACCT_CD"].cast(IntegerType()).isNotNull() &
                                    df["EXT_SEC_ID"].cast(IntegerType()).isNotNull() &
                                    df["ASOF_DATE"].cast(StringType()).isNotNull()&
                                    df["LONG_SHORT_IND"].cast(StringType()).isNotNull() &
                                    df["QTY_SOD"].cast(IntegerType()).isNotNull() &
                                    df["COST"].cast(DoubleType()).isNotNull()&
                                    df["UNIT_COST"].cast(DoubleType()).isNotNull() &
                                    df["MKT_VAL_SOD"].cast(DoubleType()).isNotNull() &
                                    df["UNREALIZED_GAIN_LOSS"].cast(StringType()).isNotNull()))
        if  mismatched_row.count() > 0:
            print("Schema validation failed.")
            print("Mismatched row:")
            mismatched_row.show()
        else:
            print("Schema validation successful.")
    else:
        print("Schema validation failed.")
except : 
    print("")
# Out:
# Data frame schema:  StructType([StructField('ACCT_CD', IntegerType(), True), StructField('ASOF_DATE', IntegerType(), True), StructField('LONG_SHORT_IND', StringType(), True), StructField('QTY_SOD', StringType(), True), StructField('COST', IntegerType(), True), StructField('UNIT_COST', DoubleType(), True), StructField('MKT_VAL_SOD', DoubleType(), True), StructField('UNREALIZED_GAIN_LOSS', DoubleType(), True), StructField('ACCRUED_INTEREST', StringType(), True)])
# Expected Schema:  StructType([StructField('ACCT_CD', IntegerType(), True), StructField('EXT_SEC_ID', IntegerType(), True), StructField('ASOF_DATE', StringType(), True), StructField('LONG_SHORT_IND', StringType(), True), StructField('QTY_SOD', IntegerType(), True), StructField('COST', DoubleType(), True), StructField('UNIT_COST', DoubleType(), True), StructField('MKT_VAL_SOD', DoubleType(), True), StructField('UNREALIZED_GAIN_LOSS', StringType(), True)])
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[15], line 26
#      22 print('Expected Schema: ', expected_schema)
#      24 if (col in df.columns for col in expected_schema.fieldNames()):
#      25     mismatched_row = df.filter(~(df["ACCT_CD"].cast(IntegerType()).isNotNull() &
# ---> 26                                  df["EXT_SEC_ID"].cast(IntegerType()).isNotNull() &
#      27                                  df["ASOF_DATE"].cast(StringType()).isNotNull()&
#      28                                  df["LONG_SHORT_IND"].cast(StringType()).isNotNull() &
#      29                                  df["QTY_SOD"].cast(IntegerType()).isNotNull() &
#      30                                  df["COST"].cast(DoubleType()).isNotNull()&
#      31                                  df["UNIT_COST"].cast(DoubleType()).isNotNull() &
#      32                                  df["MKT_VAL_SOD"].cast(DoubleType()).isNotNull() &
#      33                                  df["UNREALIZED_GAIN_LOSS"].cast(StringType()).isNotNull()))
#      34     if  mismatched_row.count() > 0:
#      35         print("Schema validation failed.")
#
# File ~/.local/lib/python3.11/site-packages/pyspark/sql/dataframe.py:2928, in DataFrame.__getitem__(self, item)
#    2856 """Returns the column as a :class:`Column`.
#    2857
#    2858 .. versionadded:: 1.3.0
#    (...)
#    2925 +---+----+
#    2926 """
#    2927 if isinstance(item, str):
# -> 2928     jc = self._jdf.apply(item)
#    2929     return Column(jc)
#    2930 elif isinstance(item, Column):
#
# File ~/.local/lib/python3.11/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/.local/lib/python3.11/site-packages/pyspark/errors/exceptions/captured.py:175, in capture_sql_exception.<locals>.deco(*a, **kw)
#     171 converted = convert_exception(e.java_exception)
#     172 if not isinstance(converted, UnknownException):
#     173     # Hide where the exception came from that shows a non-Pythonic
#     174     # JVM exception message.
# --> 175     raise converted from None
#     176 else:
#     177     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `EXT_SEC_ID` cannot be resolved. Did you mean one of the following? [`ACCT_CD`, `ASOF_DATE`, `LONG_SHORT_IND`, `QTY_SOD`, `COST`, `UNIT_COST`, `MKT_VAL_SOD`, `UNREALIZED_GAIN_LOSS`, `ACCRUED_INTEREST`].

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions
from pyspark.sql.functions import to_date
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DoubleType, DateType

# Create a SparkSession
spark = SparkSession.builder.getOrCreate()

constraint_expr = functions.expr("LONG_SHORT_IND IN ('L', 'S')")

expected_schema = StructType([
    StructField("ACCT_CD", IntegerType(), nullable=True),
    StructField("EXT_SEC_ID", IntegerType(), nullable=True),
    # StructField("ASOF_DATE", StringType(), nullable=True),
    StructField("ASOF_DATE", DateType(), nullable=True),
    StructField("LONG_SHORT_IND", StringType(), nullable=True, metadata={"constraint": constraint_expr}),
    StructField("QTY_SOD", IntegerType(), nullable=True),
    StructField("COST", DoubleType(), nullable=True),
    StructField("UNIT_COST", DoubleType(), nullable=True),
    StructField("MKT_VAL_SOD", DoubleType(), nullable=True),
    StructField("UNREALIZED_GAIN_LOSS", StringType(), nullable=True)
])

df = spark.read.csv("CRD_Position_202212124.csv", nullValue="", header=True, inferSchema=True)

print('Data frame schema: ', df.schema)
print('Expected Schema: ', expected_schema)

# Check if all expected columns exist in the DataFrame
expected_columns = set([field.name for field in expected_schema.fields])
df_columns = set(df.columns)

if expected_columns.issubset(df_columns):
    # Perform schema validation
    allowed_values = ['L','S']
    mismatched_row = df.filter(~(
        df["ACCT_CD"].cast(IntegerType()).isNotNull() &
        df["EXT_SEC_ID"].cast(IntegerType()).isNotNull() &
        to_date(df["ASOF_DATE"], "dd/MM/yyyy").isNotNull()&
        # df["ASOF_DATE"].cast(StringType()).isNotNull() &
        df["LONG_SHORT_IND"].cast(StringType()).isin(allowed_values) &
        df["QTY_SOD"].cast(IntegerType()).isNotNull() &
        df["COST"].cast(DoubleType()).isNotNull() &
        df["UNIT_COST"].cast(DoubleType()).isNotNull() &
        df["MKT_VAL_SOD"].cast(DoubleType()).isNotNull() &
        df["UNREALIZED_GAIN_LOSS"].cast(StringType()).isNotNull()
    ))
    
    if mismatched_row.count() > 0:
        print("Schema validation failed.")
        print("Mismatched row:")
        mismatched_row.show()
        mismatched_rows_str = "\n".join([str(row) for row in mismatched_row.collect()])
        mismatched_row.write.csv("erroneous_rows.csv", header=True, mode="overwrite")
        error_message = f"Schema validation failed. Mismatched rows:\n{mismatched_rows_str}"
        with open("error_message.txt", "w+") as file:
            file.write(error_message)
        cleaned_df = df.exceptAll(mismatched_row)
        # cleaned_df = df.dropna(subset=[col.name for col in expected_schema.fields])
        print(cleaned_df.show())

    else:
        print("Schema validation successful.")
else:
    print("Schema validation failed. Column mismatch between DataFrame and expected schema.")
# Out:
# Data frame schema:  StructType([StructField('ACCT_CD', IntegerType(), True), StructField('EXT_SEC_ID', StringType(), True), StructField('ASOF_DATE', StringType(), True), StructField('LONG_SHORT_IND', StringType(), True), StructField('QTY_SOD', IntegerType(), True), StructField('COST', DoubleType(), True), StructField('UNIT_COST', DoubleType(), True), StructField('MKT_VAL_SOD', DoubleType(), True), StructField('UNREALIZED_GAIN_LOSS', StringType(), True), StructField('ACCRUED_INTEREST', StringType(), True)])
# Expected Schema:  StructType([StructField('ACCT_CD', IntegerType(), True), StructField('EXT_SEC_ID', IntegerType(), True), StructField('ASOF_DATE', DateType(), True), StructField('LONG_SHORT_IND', StringType(), True), StructField('QTY_SOD', IntegerType(), True), StructField('COST', DoubleType(), True), StructField('UNIT_COST', DoubleType(), True), StructField('MKT_VAL_SOD', DoubleType(), True), StructField('UNREALIZED_GAIN_LOSS', StringType(), True)])
# Schema validation failed.
# Mismatched row:
# +-------+----------+----------+--------------+-------+--------+------------+-----------+--------------------+----------------+
# |ACCT_CD|EXT_SEC_ID| ASOF_DATE|LONG_SHORT_IND|QTY_SOD|    COST|   UNIT_COST|MKT_VAL_SOD|UNREALIZED_GAIN_LOSS|ACCRUED_INTEREST|
# +-------+----------+----------+--------------+-------+--------+------------+-----------+--------------------+----------------+
# |   1465|        er|02/08/2022|             L|    758|29415.55|  38.8067942|    1111.58|             9250.03|            null|
# |   1465|       wer|02/08/2022|             L|   2222|17911.69|373.16020833|   26316.96|             8405.27|            null|
# |   1465|    103044|02/08/2022|             S|   -231|44461.66|192.47471861|   46010.58|             1548.92|            null|
# |   1465|    205265|02/08/2022|             S|   -456|29510.47|146.09143564|   22415.94|            -7094.53|            null|
# +-------+----------+----------+--------------+-------+--------+------------+-----------+--------------------+----------------+
#
# +-------+----------+----------+--------------+-------+--------+------------+-----------+--------------------+----------------+
# |ACCT_CD|EXT_SEC_ID| ASOF_DATE|LONG_SHORT_IND|QTY_SOD|    COST|   UNIT_COST|MKT_VAL_SOD|UNREALIZED_GAIN_LOSS|ACCRUED_INTEREST|
# +-------+----------+----------+--------------+-------+--------+------------+-----------+--------------------+----------------+
# |   1465|    137217|02/08/2022|             L|     99|31819.92|321.41333333|  3333333.0|            16131.72|            null|
# |   1465|     72877|02/08/2022|             L|    970|52134.48|  53.7468866|    58035.1|             5900.62|            null|
# |   1465|     74075|02/08/2022|             L|    442|72279.11|163.52739819|    74344.4|             2065.29|            null|
# |   1465|    217927|02/08/2022|             L|    146| 5924.25| 40.57705479|    10497.4|             4573.15|            null|
# |   1465|     79524|02/08/2022|             L|    558|35129.47| 62.95603943|   29479.14|            -5650.33|            null|
# |   1465|     54655|02/08/2022|             L|   1796|31953.96| 17.79173719| 19793.5364|         -12160.4236|            null|
# |   1465|    115926|02/08/2022|             L|   1074|41898.41| 39.01155493| 48506.7804|           6608.3704|            null|
# |   1465|     65898|02/08/2022|             L|    332| 9249.13|  27.8588253|   23528.84|   14279.71/23528.84|            null|
# |   1465|     75065|02/08/2022|             L|    918|53684.16| 58.47947712|    32726.7|           -20957.46|            null|
# +-------+----------+----------+--------------+-------+--------+------------+-----------+--------------------+----------------+
#
# None

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

directory_path = "testcsv/"
file_pattern = "De*.csv"
full_path = f"{directory_path}/{file_pattern}"
df = spark.read.csv(full_path, header=True, inferSchema=True)
df.count()
# Out:
# 100

# %%
import pandas as pd
import datetime as dt
from pandas_schema import Column, Schema
from pandas_schema.validation import CanConvertValidation, DateFormatValidation, InListValidation, CustomElementValidation

start_time = dt.datetime.now()

df = pd.read_csv("erroneous_CRD_Position_202212124_200.csv")

def validate_not_empty(value):
    if isinstance(value, str):
        return value.strip() != '' 
    else:
        return pd.notnull(value)

validation_functions = CustomElementValidation(validate_not_empty, 'Mandatory col should not be empty')

expected_schema = Schema([
    Column("ACCT_CD", [CanConvertValidation(int), validation_functions]),
    Column("EXT_SEC_ID", [CanConvertValidation(int)]),
    Column("ASOF_DATE", [DateFormatValidation(date_format='%Y-%m-%d %H:%M:%S.%f')]),
    Column("LONG_SHORT_IND", [InListValidation(['L','S']), validation_functions]),
    Column("QTY_SOD", [CanConvertValidation(int)]),
    Column("COST", [CanConvertValidation(float)]),
    Column("UNIT_COST", [CanConvertValidation(float)]),
    Column("MKT_VAL_SOD", [CanConvertValidation(float)])
])

# Validate DataFrame against the expected schema
errors = expected_schema.validate(df, columns=['ACCT_CD', 'EXT_SEC_ID', 'ASOF_DATE', 'LONG_SHORT_IND', 'QTY_SOD', 'COST', 'UNIT_COST', 'MKT_VAL_SOD'])
# erdf = pd.DataFrame(errors)
# print(erdf)
if errors:
    erdf = pd.DataFrame(errors)
    print(erdf)
    # erdf.to_('err_message_csv.csv')
    print(erdf.loc[:])
    # erstr = ''+f"Row: {erdf[0].loc[:]}, Column: {erdf[1].loc[:]} - Error: {erdf[2].loc[:]}"
    # erstr = ''+ erdf.to_string
    # error_file = open("err_mes.txt", "w")
    # error_file.write(erstr + "\n")
    
    # error_message = f"Schema validation failed. Mismatched rows:\n{erdf}"
    with open("err_mes.txt", "w+") as file:
        file.write(erdf.to_string())
    # Create a file for writing errors into
    error_file = open("err_messages.txt", "w")
    
    # Create an empty DataFrame to store erroneous rows
    erroneous_rows = pd.DataFrame(columns=df.columns)
    
    # Create a set to store the indices of erroneous rows
    erroneous_indices = set()
    
    print("Schema validation failed. Mismatched rows:")
    print(type(errors))
    for error in errors:
        error_message = f"Row: {error.row}, Column: {error.column} - Error: {error.message}"
        print(error_message)
        
        error_file.write(error_message + "\n")
        
        if error.row not in erroneous_indices:
            # Collect the erroneous row into the DataFrame
            erroneous_rows = erroneous_rows._append(df.iloc[error.row])
            erroneous_indices.add(error.row)
            
    erroneous_rows.to_csv("er_rows.csv", index=False)
    error_file.close()
    
    df = df.drop(list(erroneous_indices))
    df = df.reset_index(drop=True)

else:
    print("Schema validation successful")
    
print("Dataframe after dropping erroneous rows: ")
print(df)  
    
print(f"Validation Time using pandas: {(dt.datetime.now() - start_time).total_seconds()} seconds")


# git pe repo
# timesheet
# Out:
#                                                      0
# 0    {row: 1, column: "ACCT_CD"}: "nan" cannot be c...
# 1    {row: 1, column: "ACCT_CD"}: "nan" Mandatory c...
# 2    {row: 2, column: "ASOF_DATE"}: "1970-01-01" do...
# 3    {row: 2, column: "LONG_SHORT_IND"}: "M" is not...
# 4    {row: 5, column: "ASOF_DATE"}: "1970-01-01 05:...
# ..                                                 ...
# 211  {row: 195, column: "ACCT_CD"}: "nan" Mandatory...
# 212  {row: 195, column: "LONG_SHORT_IND"}: "K" is n...
# 213  {row: 196, column: "ASOF_DATE"}: "1970-01-01 0...
# 214  {row: 197, column: "ASOF_DATE"}: "19-01-01 05:...
# 215  {row: 198, column: "ASOF_DATE"}: "19-01-01 05:...
#
# [216 rows x 1 columns]
#                                                      0
# 0    {row: 1, column: "ACCT_CD"}: "nan" cannot be c...
# 1    {row: 1, column: "ACCT_CD"}: "nan" Mandatory c...
# 2    {row: 2, column: "ASOF_DATE"}: "1970-01-01" do...
# 3    {row: 2, column: "LONG_SHORT_IND"}: "M" is not...
# 4    {row: 5, column: "ASOF_DATE"}: "1970-01-01 05:...
# ..                                                 ...
# 211  {row: 195, column: "ACCT_CD"}: "nan" Mandatory...
# 212  {row: 195, column: "LONG_SHORT_IND"}: "K" is n...
# 213  {row: 196, column: "ASOF_DATE"}: "1970-01-01 0...
# 214  {row: 197, column: "ASOF_DATE"}: "19-01-01 05:...
# 215  {row: 198, column: "ASOF_DATE"}: "19-01-01 05:...
#
# [216 rows x 1 columns]
# Schema validation failed. Mismatched rows:
# <class 'list'>
# Row: 1, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 1, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 2, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 2, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 5, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 5, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 5, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 7, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 7, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 9, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 9, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 9, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 10, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 11, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 13, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 13, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 14, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 14, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 17, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 17, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 17, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 19, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 19, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 22, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 22, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 22, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 23, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 24, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 26, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 26, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 27, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 27, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 30, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 30, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 30, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 32, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 32, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 35, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 35, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 35, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 36, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 37, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 39, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 39, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 40, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 40, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 43, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 43, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 43, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 45, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 45, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 48, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 48, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 48, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 49, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 50, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 52, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 52, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 53, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 53, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 56, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 56, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 56, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 58, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 58, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 61, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 61, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 61, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 62, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 63, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 65, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 65, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 66, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 66, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 69, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 69, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 69, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 71, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 71, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 74, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 74, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 74, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 75, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 76, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 78, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 78, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 79, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 79, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 82, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 82, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 82, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 84, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 84, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 87, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 87, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 87, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 88, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 89, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 91, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 91, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 92, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 92, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 95, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 95, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 95, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 97, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 97, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 100, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 100, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 100, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 101, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 102, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 104, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 104, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 105, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 105, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 108, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 108, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 108, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 110, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 110, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 113, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 113, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 113, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 114, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 115, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 117, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 117, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 118, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 118, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 121, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 121, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 121, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 123, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 123, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 126, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 126, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 126, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 127, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 128, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 130, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 130, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 131, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 131, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 134, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 134, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 134, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 136, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 136, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 139, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 139, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 139, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 140, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 141, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 143, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 143, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 144, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 144, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 147, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 147, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 147, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 149, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 149, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 152, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 152, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 152, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 153, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 154, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 156, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 156, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 157, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 157, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 160, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 160, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 160, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 162, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 162, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 165, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 165, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 165, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 166, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 167, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 169, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 169, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 170, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 170, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 173, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 173, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 173, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 175, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 175, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 178, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 178, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 178, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 179, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 180, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 182, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 182, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 183, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 183, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 186, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 186, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 186, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 188, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 188, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 191, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 191, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 191, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 192, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 193, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 195, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 195, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 195, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 196, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 197, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 198, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Dataframe after dropping erroneous rows:
#     ACCT_CD  EXT_SEC_ID                ASOF_DATE LONG_SHORT_IND  QTY_SOD
# 0    1465.0       54655  1970-01-01 05:30:44.775              L     1796  \
# 1    1465.2       72877  1970-01-01 05:30:44.775              L      970
# 2    1465.0       74075  1970-01-01 05:30:44.775              L      442
# 3    1465.0       75065  1970-01-01 05:30:44.775              L      918
# 4    1465.0      115926  1970-01-01 05:30:44.775              L     1074
# ..      ...         ...                      ...            ...      ...
# 86   1483.0       75065  1970-01-01 05:30:44.775              L      918
# 87   1484.0      115926  1970-01-01 05:30:44.775              L     1074
# 88   1484.0       79188  1970-01-01 05:30:44.775              L     2222
# 89   1484.0       79188  1970-01-01 05:30:44.775              L     2222
# 90   1482.0       79188  1970-01-01 05:30:44.775              L     2222
#
#         COST   UNIT_COST  MKT_VAL_SOD UNREALIZED_GAIN_LOSS  ACCRUED_INTEREST
# 0   31953.96   17.791737   19793.5364          -12160.4236               NaN
# 1   52134.48   53.746887   58035.1000              5900.62               NaN
# 2   72279.11  163.527398   74344.4000              2065.29               NaN
# 3   53684.16   58.479477   32726.7000            -20957.46               NaN
# 4   41898.41   39.011555   48506.7804            6608.3704               NaN
# ..       ...         ...          ...                  ...               ...
# 86  53684.16   58.479477   32726.7000            -20957.46               NaN
# 87  41898.41   39.011555   48506.7804            6608.3704               NaN
# 88  17911.69  373.160208   26316.9600              8405.27               NaN
# 89  17911.69  373.160208   26316.9600              8405.27               NaN
# 90  17911.69  373.160208   26316.9600              8405.27               NaN
#
# [91 rows x 10 columns]
# Validation Time using pandas: 0.208231 seconds

# %%
l=[1,2,3,4,5]
print(l[:])
# Out:
# [1, 2, 3, 4, 5]

# %%
import pandas as pd
import datetime as dt
from pandas_schema import Column, Schema
from pandas_schema.validation import CanConvertValidation, DateFormatValidation, InListValidation, CustomElementValidation

start_time = dt.datetime.now()

df = pd.read_csv("erroneous_CRD_Position_202212124_200.csv")

def validate_not_empty(value):
    if isinstance(value, str):
        return value.strip() != ''
    else:
        return pd.notnull(value)

validation_functions = CustomElementValidation(validate_not_empty, 'Mandatory col should not be empty')

expected_schema = Schema([
    Column("ACCT_CD", [CanConvertValidation(int), validation_functions]),
    Column("EXT_SEC_ID", [CanConvertValidation(int)]),
    Column("ASOF_DATE", [DateFormatValidation(date_format='%Y-%m-%d %H:%M:%S.%f')]),
    Column("LONG_SHORT_IND", [InListValidation(['L','S']), validation_functions]),
    Column("QTY_SOD", [CanConvertValidation(int)]),
    Column("COST", [CanConvertValidation(float)]),
    Column("UNIT_COST", [CanConvertValidation(float)]),
    Column("MKT_VAL_SOD", [CanConvertValidation(float)])
])

# Validate DataFrame against the expected schema
errors = expected_schema.validate(df, columns=['ACCT_CD', 'EXT_SEC_ID', 'ASOF_DATE', 'LONG_SHORT_IND', 'QTY_SOD', 'COST', 'UNIT_COST', 'MKT_VAL_SOD'])

if errors:
    # Create a file for writing errors into
    error_file = open("er_messages.txt", "w")

    # Create a list of error messages using list comprehension
    error_messages = [f"Row: {error.row}, Column: {error.column} - Error: {error.message}" for error in errors]

    # Join the error messages using newline character
    error_message_text = "\n".join(error_messages)

    # Write the error messages to the file
    error_file.write(error_message_text)

    print("Schema validation failed. Mismatched rows:")
    print(error_message_text)

    error_file.close()

    # Get the indices of erroneous rows
    erroneous_indices = {error.row for error in errors}

    # Filter erroneous rows using boolean indexing
    erroneous_rows = df[df.index.isin(erroneous_indices)]

    erroneous_rows.to_csv("er_rows.csv", index=False)
    
    # Drop erroneous rows from the original DataFrame
    df = df.drop(list(erroneous_indices))
    df = df.reset_index(drop=True)
else:
    print("Schema validation successful")

print("Dataframe after dropping erroneous rows: ")
print(df)  

print(f"Validation Time using pandas: {(dt.datetime.now() - start_time).total_seconds()} seconds")
# Out:
# Schema validation failed. Mismatched rows:
# Row: 1, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 1, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 2, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 2, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 5, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 5, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 5, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 7, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 7, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 9, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 9, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 9, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 10, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 11, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 13, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 13, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 14, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 14, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 17, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 17, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 17, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 19, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 19, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 22, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 22, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 22, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 23, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 24, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 26, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 26, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 27, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 27, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 30, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 30, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 30, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 32, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 32, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 35, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 35, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 35, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 36, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 37, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 39, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 39, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 40, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 40, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 43, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 43, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 43, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 45, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 45, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 48, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 48, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 48, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 49, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 50, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 52, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 52, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 53, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 53, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 56, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 56, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 56, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 58, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 58, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 61, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 61, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 61, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 62, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 63, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 65, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 65, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 66, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 66, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 69, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 69, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 69, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 71, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 71, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 74, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 74, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 74, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 75, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 76, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 78, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 78, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 79, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 79, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 82, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 82, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 82, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 84, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 84, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 87, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 87, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 87, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 88, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 89, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 91, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 91, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 92, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 92, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 95, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 95, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 95, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 97, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 97, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 100, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 100, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 100, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 101, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 102, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 104, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 104, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 105, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 105, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 108, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 108, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 108, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 110, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 110, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 113, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 113, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 113, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 114, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 115, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 117, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 117, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 118, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 118, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 121, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 121, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 121, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 123, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 123, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 126, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 126, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 126, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 127, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 128, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 130, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 130, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 131, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 131, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 134, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 134, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 134, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 136, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 136, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 139, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 139, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 139, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 140, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 141, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 143, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 143, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 144, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 144, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 147, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 147, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 147, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 149, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 149, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 152, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 152, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 152, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 153, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 154, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 156, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 156, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 157, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 157, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 160, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 160, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 160, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 162, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 162, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 165, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 165, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 165, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 166, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 167, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 169, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 169, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 170, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 170, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 173, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 173, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 173, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 175, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 175, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 178, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 178, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 178, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 179, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 180, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 182, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 182, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 183, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 183, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 186, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 186, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 186, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 188, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 188, Column: LONG_SHORT_IND - Error: Mandatory col should not be empty
# Row: 191, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 191, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 191, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 192, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 193, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 195, Column: ACCT_CD - Error: cannot be converted to type <class 'int'>
# Row: 195, Column: ACCT_CD - Error: Mandatory col should not be empty
# Row: 195, Column: LONG_SHORT_IND - Error: is not in the list of legal options (L, S)
# Row: 196, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 197, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Row: 198, Column: ASOF_DATE - Error: does not match the date format string "%Y-%m-%d %H:%M:%S.%f"
# Dataframe after dropping erroneous rows:
#     ACCT_CD  EXT_SEC_ID                ASOF_DATE LONG_SHORT_IND  QTY_SOD
# 0    1465.0       54655  1970-01-01 05:30:44.775              L     1796  \
# 1    1465.2       72877  1970-01-01 05:30:44.775              L      970
# 2    1465.0       74075  1970-01-01 05:30:44.775              L      442
# 3    1465.0       75065  1970-01-01 05:30:44.775              L      918
# 4    1465.0      115926  1970-01-01 05:30:44.775              L     1074
# ..      ...         ...                      ...            ...      ...
# 86   1483.0       75065  1970-01-01 05:30:44.775              L      918
# 87   1484.0      115926  1970-01-01 05:30:44.775              L     1074
# 88   1484.0       79188  1970-01-01 05:30:44.775              L     2222
# 89   1484.0       79188  1970-01-01 05:30:44.775              L     2222
# 90   1482.0       79188  1970-01-01 05:30:44.775              L     2222
#
#         COST   UNIT_COST  MKT_VAL_SOD UNREALIZED_GAIN_LOSS  ACCRUED_INTEREST
# 0   31953.96   17.791737   19793.5364          -12160.4236               NaN
# 1   52134.48   53.746887   58035.1000              5900.62               NaN
# 2   72279.11  163.527398   74344.4000              2065.29               NaN
# 3   53684.16   58.479477   32726.7000            -20957.46               NaN
# 4   41898.41   39.011555   48506.7804            6608.3704               NaN
# ..       ...         ...          ...                  ...               ...
# 86  53684.16   58.479477   32726.7000            -20957.46               NaN
# 87  41898.41   39.011555   48506.7804            6608.3704               NaN
# 88  17911.69  373.160208   26316.9600              8405.27               NaN
# 89  17911.69  373.160208   26316.9600              8405.27               NaN
# 90  17911.69  373.160208   26316.9600              8405.27               NaN
#
# [91 rows x 10 columns]
# Validation Time using pandas: 0.022864 seconds
